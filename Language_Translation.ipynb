# %%
# importing necessary library
import os
import sys
import warnings
import transformers
import tensorflow as tf
from datasets import load_dataset
from transformers import AutoTokenizer
from transformers import TFAutoModelForSeq2SeqLM, DataCollatorForSeq2Seq
from transformers import AdamWeightDecay
from transformers import AutoTokenizer

# TFAutoModelForSeq2SeqLM  is used for many to many (sentence to sentence)
# Out:
# WARNING:tensorflow:From c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model_checkpoint = "Helsinki-NLP/opus-mt-en-ne"

# another model 
# model_checkpoint = "d2niraj555/mt5-eng2nep"

# %%
# raw_datasets = load_dataset("cfilt/iitb-english-nepali") # this dataset is not found 


raw_datasets = load_dataset("CohleM/english-to-nepali")   # this dataset runs but i cannot commit due to storage issue
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 # raw_datasets = load_dataset("cfilt/iitb-english-nepali") # this dataset is not found
# ----> 4 raw_datasets = load_dataset("CohleM/english-to-nepali")
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\load.py:2582, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2579 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    2581 # Download and prepare data
# -> 2582 builder_instance.download_and_prepare(
#    2583     download_config=download_config,
#    2584     download_mode=download_mode,
# ...

# %%
raw_datasets

# %%
raw_datasets['train'][1]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
tokenizer("Ram, this is a sentence!")

# %%
tokenizer(["Hello, this is a sentence!", "This is another sentence."])

# %%
with tokenizer.as_target_tokenizer():
    print(tokenizer(["राजनीतिक अवस्था राम्रो छैन"]))

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-ne")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-ne")

# Now you can use the model and tokenizer for translation

# %%
# 17:31
