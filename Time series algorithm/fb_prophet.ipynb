# %%
### pip install pystan
### conda install -c conda-forge fbprophet
import pandas as pd
from prophet import Prophet

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('TSLA.csv')

#taking only 2 column
df = df[['Date', 'Close']]

# %%
df.head()
# Out:
#          Date      Close
# 0  2019-05-21  41.015999
# 1  2019-05-22  38.546001
# 2  2019-05-23  39.098000
# 3  2019-05-24  38.125999
# 4  2019-05-28  37.740002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    758 non-null    object
#  1   Close   758 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 12.0+ KB

# %%
# plotting data 
df.plot()
# Out:
# <AxesSubplot: >

# %%
#ds is compulsary
df.columns = ['ds','y']
df.head()
# Out:
#            ds          y
# 0  2019-05-21  41.015999
# 1  2019-05-22  38.546001
# 2  2019-05-23  39.098000
# 3  2019-05-24  38.125999
# 4  2019-05-28  37.740002

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      758 non-null    datetime64[ns]
#  1   y       758 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 12.0 KB

# %%
dir(Prophet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_load_stan_backend',
#  '_logistic_uncertainty',
#  '_make_historical_mat_time',
#  '_make_trend_shift_matrix',
#  '_sample_uncertainty',
#  'add_country_holidays',
#  'add_group_component',
#  'add_regressor',
#  'add_seasonality',
#  'construct_holiday_dataframe',
#  'fit',
#  'flat_growth_init',
#  'flat_trend',
#  'fourier_series',
#  'initialize_scales',
#  'linear_growth_init',
#  'logistic_growth_init',
#  'make_all_seasonality_features',
#  'make_future_dataframe',
#  'make_holiday_features',
#  'make_seasonality_features',
#  'parse_seasonality_args',
#  'percentile',
#  'piecewise_linear',
#  'piecewise_logistic',
#  'plot',
#  'plot_components',
#  'predict',
#  'predict_seasonal_components',
#  'predict_trend',
#  'predict_uncertainty',
#  'predictive_samples',
#  'regressor_column_matrix',
#  'sample_model',
#  'sample_model_vectorized',
#  'sample_posterior_predictive',
#  'sample_predictive_trend',
#  'sample_predictive_trend_vectorized',
#  'set_auto_seasonalities',
#  'set_changepoints',
#  'setup_dataframe',
#  'validate_column_name',
#  'validate_inputs']

# %%
# Initialize the Model
model=Prophet()

# %%
# checking the column 
df.columns
# Out:
# Index(['ds', 'y'], dtype='object')

# %%
df.dropna(axis=0,inplace=True)

# %%
df.head()
# Out:
#           ds          y
# 0 2019-05-21  41.015999
# 1 2019-05-22  38.546001
# 2 2019-05-23  39.098000
# 3 2019-05-24  38.125999
# 4 2019-05-28  37.740002

# %%
model.fit(df)
# Out:
# 22:27:14 - cmdstanpy - INFO - Chain [1] start processing
# 22:27:14 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.component_modes
# Out:
# {'additive': ['yearly',
#   'weekly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
### Create future dates of 365 days period
future_dates=model.make_future_dataframe(periods=365)

# %%
future_dates.tail()
# Out:
#              ds
# 1118 2023-05-16
# 1119 2023-05-17
# 1120 2023-05-18
# 1121 2023-05-19
# 1122 2023-05-20

# %%
prediction=model.predict(future_dates)

# %%
prediction.head()
# Out:
#           ds       trend  ...  multiplicative_terms_upper       yhat
# 0 2019-05-21  144.741962  ...                         0.0  31.167018
# 1 2019-05-22  143.888289  ...                         0.0  31.151951
# 2 2019-05-23  143.034616  ...                         0.0  27.731548
# 3 2019-05-24  142.180943  ...                         0.0  27.063636
# 4 2019-05-28  138.766250  ...                         0.0  36.874791
#
# [5 rows x 19 columns]

# %%
### plotting the predicted projection
model.plot(prediction)
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\prophet\plot.py:71: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
# Time Series Analysis

# 1960-1962
# Cross Validation
# 1960-61---Train dataset
# 1961-62--Test dataset
# 1962-63---Validation

# %%
df.head()
# Out:
#           ds          y
# 0 2019-05-21  41.015999
# 1 2019-05-22  38.546001
# 2 2019-05-23  39.098000
# 3 2019-05-24  38.125999
# 4 2019-05-28  37.740002

# %%
# using cross validation for
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
df_cv.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 22:27:16 - cmdstanpy - INFO - Chain [1] start processing
# 22:27:16 - cmdstanpy - INFO - Chain [1] done processing
#           ds        yhat  yhat_lower  yhat_upper           y     cutoff
# 0 2021-05-21  631.463446  593.266487  670.414413  580.880005 2021-05-20
# 1 2021-05-24  639.145723  600.174317  676.959633  606.440002 2021-05-20
# 2 2021-05-25  642.886580  603.573458  681.500112  604.690002 2021-05-20
# 3 2021-05-26  645.174920  604.088055  685.331499  619.130005 2021-05-20
# 4 2021-05-27  647.534914  607.577175  686.985893  630.849976 2021-05-20

# %%
# using performance metrics
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon          mse       rmse  ...     mdape     smape  coverage
# 0 36 days  2757.778330  52.514554  ...  0.079606  0.074618      0.32
# 1 39 days  2663.084213  51.605079  ...  0.070480  0.072092      0.36
# 2 40 days  2620.466495  51.190492  ...  0.070480  0.070112      0.36
# 3 41 days  2562.195557  50.618135  ...  0.070480  0.067750      0.36
# 4 42 days  2536.480990  50.363489  ...  0.070480  0.066452      0.36
#
# [5 rows x 8 columns]

# %%
df_p.head()
# Out:
#   horizon          mse       rmse  ...     mdape     smape  coverage
# 0 36 days  2757.778330  52.514554  ...  0.079606  0.074618      0.32
# 1 39 days  2663.084213  51.605079  ...  0.070480  0.072092      0.36
# 2 40 days  2620.466495  51.190492  ...  0.070480  0.070112      0.36
# 3 41 days  2562.195557  50.618135  ...  0.070480  0.067750      0.36
# 4 42 days  2536.480990  50.363489  ...  0.070480  0.066452      0.36
#
# [5 rows x 8 columns]

# %%
df_p
# Out:
#      horizon           mse        rmse  ...     mdape     smape  coverage
# 0    36 days   2757.778330   52.514554  ...  0.079606  0.074618      0.32
# 1    39 days   2663.084213   51.605079  ...  0.070480  0.072092      0.36
# 2    40 days   2620.466495   51.190492  ...  0.070480  0.070112      0.36
# 3    41 days   2562.195557   50.618135  ...  0.070480  0.067750      0.36
# 4    42 days   2536.480990   50.363489  ...  0.070480  0.066452      0.36
# ..       ...           ...         ...  ...       ...       ...       ...
# 224 361 days   6510.098152   80.685179  ...  0.053766  0.079518      1.00
# 225 362 days   6975.018284   83.516575  ...  0.071951  0.083384      1.00
# 226 363 days   7986.734106   89.368530  ...  0.077418  0.089712      1.00
# 227 364 days   8818.672341   93.907786  ...  0.077418  0.094718      1.00
# 228 365 days  10558.512076  102.754621  ...  0.078176  0.103959      1.00
#
# [229 rows x 8 columns]
